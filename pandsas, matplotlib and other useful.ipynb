# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Dataframe DSL

# %%
df = pd.read_csv("C:/Users/VIBIN/Desktop/practice/data/insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# sex         1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# charges     1338 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.2+ KB

# %%
df.shape #find the number of rows and columns
# Out:
# (1338, 7)

# %%
df.shape #df.shape[0]
         #df.shape[1]
# Out:
# (1338, 7)

# %%
df.dtypes #column types
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.select_dtypes(include=[np.int64,object]).head()
# Out:
#    age     sex  children smoker     region
# 0   19  female         0    yes  southwest
# 1   18    male         1     no  southeast
# 2   28    male         3     no  southeast
# 3   33    male         0     no  northwest
# 4   32    male         0     no  northwest

# %%
df.sample(10)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 488    44  female  38.060         0    yes  southeast  48885.13561
# 820    45    male  33.700         1     no  southwest   7445.91800
# 1219   38  female  30.210         3     no  northwest   7537.16390
# 840    21    male  31.100         0     no  southwest   1526.31200
# 531    62  female  31.730         0     no  northeast  14043.47670
# 178    46  female  28.900         2     no  southwest   8823.27900
# 1116   41    male  29.640         5     no  northeast   9222.40260
# 238    19    male  29.070         0    yes  northwest  17352.68030
# 29     31    male  36.300         2    yes  southwest  38711.00000
# 254    50    male  31.825         0    yes  northeast  41097.16175

# %%
df [df.region =="southwest"].sample(10)
# Out:
#       age     sex   bmi  children smoker     region      charges
# 310    50    male  26.6         0     no  southwest   8444.47400
# 1268   20  female  33.3         0     no  southwest   1880.48700
# 888    22    male  39.5         0     no  southwest   1682.59700
# 363    21  female  26.4         1     no  southwest   2597.77900
# 132    53  female  35.9         2     no  southwest  11163.56800
# 817    23    male  37.1         3     no  southwest   3597.59600
# 328    64  female  33.8         1    yes  southwest  47928.03000
# 306    28  female  27.5         2     no  southwest  20177.67113
# 177    54    male  29.2         1     no  southwest  10436.09600
# 547    54  female  46.7         2     no  southwest  11538.42100

# %%
df.sort_values("region")
# Out:
#      age     sex     bmi  children smoker     region      charges
# 668   62    male  32.015         0    yes  northeast  45710.20785
# 319   32    male  37.335         1     no  northeast   4667.60765
# 844   53    male  30.495         0     no  northeast  10072.05505
# 317   54    male  32.775         0     no  northeast  10435.06525
# 315   52    male  33.250         0     no  northeast   9722.76950
# 850   37  female  30.780         0    yes  northeast  37270.15120
# 852   46  female  35.530         0    yes  northeast  42111.66470
# 853   53  female  23.750         2     no  northeast  11729.67950
# 854   49  female  23.845         3    yes  northeast  24106.91255
# 308   58    male  34.865         0     no  northeast  11944.59435
# 863   36  female  19.855         0     no  northeast   5458.04645
# 868   61    male  23.655         0     no  northeast  13129.60345
# 874   44    male  21.850         3     no  northeast   8891.13950
# ...

# %%
df.groupby("sex").bmi.agg([np.mean,len])
# Out:
#              mean    len
# sex
# female  30.377749  662.0
# male    30.943129  676.0

# %%
df.pivot_table(index=["sex","region"],values=["bmi"],aggfunc = [np.mean,len])
# Out:
#                        mean    len
#                         bmi    bmi
# sex    region
# female northeast  29.324317  161.0
#        northwest  29.277957  164.0
#        southeast  32.671257  175.0
#        southwest  30.060494  162.0
# male   northeast  29.024540  163.0
#        northwest  29.120155  161.0
#        southeast  33.990000  189.0
#        southwest  31.129448  163.0

# %%
df.groupby("sex").bmi.mean()
# Out:
# sex
# female    30.377749
# male      30.943129
# Name: bmi, dtype: float64

# %%
df.groupby("sex").bmi.agg([np.mean,len]).reset_index()
# Out:
#       sex       mean    len
# 0  female  30.377749  662.0
# 1    male  30.943129  676.0

# %%
df.iloc[5:10]
# Out:
#    age     sex    bmi  children smoker     region      charges
# 5   31  female  25.74         0     no  southeast   3756.62160
# 6   46  female  33.44         1     no  southeast   8240.58960
# 7   37  female  27.74         3     no  northwest   7281.50560
# 8   37    male  29.83         2     no  northeast   6406.41070
# 9   60  female  25.84         0     no  northwest  28923.13692

# %%
df.pivot_table(index=["sex","region"],values=["bmi"],aggfunc=[np.mean, len])
# Out:
#                        mean    len
#                         bmi    bmi
# sex    region
# female northeast  29.324317  161.0
#        northwest  29.277957  164.0
#        southeast  32.671257  175.0
#        southwest  30.060494  162.0
# male   northeast  29.024540  163.0
#        northwest  29.120155  161.0
#        southeast  33.990000  189.0
#        southwest  31.129448  163.0

# %% [markdown]
# # FIND TOP 10 MOVIES FROM THE MOVIELENS DATASET
# 1. create a dataframe for movies.csv
# 2. create a dataframe for ratings.csv
# 3. Find avg rating and number of rating for each movieId based on ratings dataframe
# 4. Select movies that have got 100+ ratings
# 5. Merge with movies dataframe
# 6. Top 10 movies based on avg ratings
# 7. display movieId, title, avg_rating

# %%
#loading movies and ratings dataset 
movies = pd.read_csv('C:/Users/VIBIN/Desktop/practice/data/movielens/movies.csv')
ratings = pd.read_csv('C:/Users/VIBIN/Desktop/practice/data/movielens/ratings.csv')

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       16     4.0  1217897793
# 1       1       24     1.5  1217895807
# 2       1       32     4.0  1217896246
# 3       1       47     4.0  1217896556
# 4       1       50     4.0  1217896523

# %%
#find avg rating and number of rating for each movie id based on rating dataframe
ratings.groupby('movieId').rating.agg([np.mean,len]).head(10)
# Out:
#              mean    len
# movieId
# 1        3.907328  232.0
# 2        3.353261   92.0
# 3        3.189655   58.0
# 4        2.818182   11.0
# 5        3.250000   62.0
# 6        4.073913  115.0
# 7        3.381818   55.0
# 8        3.666667    3.0
# 9        2.869565   23.0
# 10       3.600000  135.0

# %%
#select that have 100+ rating
ratings.groupby('movieId').rating.agg([np.mean,len]).query("len > 100").head()
# Out:
#              mean    len
# movieId
# 1        3.907328  232.0
# 6        4.073913  115.0
# 10       3.600000  135.0
# 21       3.490741  108.0
# 32       3.939614  207.0

# %%
agg = ratings.groupby("movieId").rating.agg([np.mean, len]).query("len >= 100").reset_index()
agg.head()
# Out:
#    movieId      mean    len
# 0        1  3.907328  232.0
# 1        6  4.073913  115.0
# 2       10  3.600000  135.0
# 3       17  3.930000  100.0
# 4       21  3.490741  108.0

# %%
#merge two data frames
pd.merge(movies, agg, on ='movieId').head()
# Out:
#    movieId                         title  \
# 0        1              Toy Story (1995)
# 1        6                   Heat (1995)
# 2       10              GoldenEye (1995)
# 3       17  Sense and Sensibility (1995)
# 4       21             Get Shorty (1995)
#
#                                         genres      mean    len
# 0  Adventure|Animation|Children|Comedy|Fantasy  3.907328  232.0
# 1                        Action|Crime|Thriller  4.073913  115.0
# 2                    Action|Adventure|Thriller  3.600000  135.0
# 3                                Drama|Romance  3.930000  100.0
# 4                        Comedy|Crime|Thriller  3.490741  108.0

# %% [markdown]
# # Basic Plotting with matplotlib

# %%
# %matplotlib notebook

# %%
import matplotlib as mpl
mpl.get_backend()
# Out:
# 'nbAgg'

# %%
import matplotlib.pyplot as plt
plt.plot?

# %%
plt.plot(3,2,'.')#arguments will be interpreted as x y pairs. The argument '.' shows how it needs to be portrayed
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

fig = Figure()
canvas = FigureCanvasAgg(fig)

ax = fig.add_subplot(111)#111 means one plot
ax.plot(3, 2, '.')
canvas.print_png('test.png')

# %%
# %%html
# <img src='test.png'/>
# #scripting layer does a lot of work done withing inside it s functions
# Out:
# <img src='test.png'/>
# #scripting layer does a lot of work done withing inside it s functions

# %%
plt.figure()
plt.plot(3,2, 'o')
ax = plt.gca()
ax.axis([0,6,0,10])
# Out:
# <img src="data:image/png;base64,..." width="640">
# [0, 6, 0, 10]

# %%
plt.figure()
plt.plot(3,1, 'o')
plt.plot(1,2, 'o')
plt.plot(2,1, 'o')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-c644966feb95> in <module>()
# ----> 1 plt.figure()
#       2 plt.plot(3,1, 'o')
#       3 plt.plot(1,2, 'o')
#       4 plt.plot(2,1, 'o')
#
# NameError: name 'plt' is not defined

# %%
ax=plt.gca()
ax.get_children()
# Out:
# ...
#  Text(0.5,1,''),
#  Text(0,1,''),
#  Text(1,1,''),
# ...

# %% [markdown]
# # Scatter Plots

# %% [markdown]
# These are basically based n numpy arrays.Give a and y as arguments.

# %%
import numpy as np 
x = np.array([1,2,4,5,6,7,8])
y = x **7
plt.figure()
plt.scatter(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x = np.array([1,2,3,4,5,6,7,8])
y = x**6
colors = ['green']*(len(x)-1)#removing last green in order to be replaced with red
colors.append('red')
plt.figure()
plt.scatter(x, y, s=10, c=colors)#s determines the size of the data points
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
zip_generator = zip([1,2,3,4,5,6,7],[1,4,9,16,25,36,49])
list(zip_generator) #zipis lazy so require a list to see the data
#sip takes elemnts from two list and bind them together and return a list of tuples
# Out:
# [(1, 1), (2, 4), (3, 9), (4, 16), (5, 25), (6, 36), (7, 49)]

# %%
plt.figure()
plt.scatter(x[:2],y[:2],s=100,c='red',label='Tall students')
plt.scatter(x[2:],y[2:],s=100,c='blue',label='short students')
plt.xlabel('Then number of students')
plt.ylabel('their height')
plt.title('Weird Relationships')
plt.legend(loc=4,frameon=False,title='Legend')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.gca().get_children()
# Out:
# ...
#  Text(0.5,1,'Weird Relationships'),
#  Text(0,1,''),
#  Text(1,1,''),
# ...

# %%
legend= plt.gca().get_children()[-2]

# %%
legend.get_children()[0].get_children()[1].get_children()[0].get_children()

# %%
from matplotlib.artist import Artist

def rec_gc(art, depth=0):
    if isinstance(art, Artist):
        print(" " * depth + str(art) )
        for child in art.get_children():
            rec_gc(child, depth+2)
rec_gc(legend)
# legend itself has path areas and path collections         
#THus matplot lib is calling the scripting interface , create figuresm subplots and axis. Load thes axis with different artist
#which the back end renders to the screen or some other medion like a file
# Out:
# Legend
# ...
#       Text(0,0,'Legend')
# ...
#             Text(0,0,'Tall students')
# ...
#             Text(0,0,'short students')
#   FancyBboxPatch(418.931,59.7444;150.125x67)

# %%
linear_data = np.array([1,2,3,4,5,6,7,8])
quadratic_data = linear_data**2
plt.figure()
plt.plot(linear_data,'-o', quadratic_data, '-o')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %% [markdown]
# So there are a couple of things which are new about this versus the scatter plots. First, we only gave y-axes values to our plot call, no x axes values. Instead, the plot function was smart enough to figure out that what we wanted was to use the index of the series as the x value. Which is pretty handy when you want to make quick plots.
# Second we see that the plot identifies this as two series of data and that the colors of the data from the series are different including the data points and the lines between the data points. This is different from the scatter plot which required us to label the lines directly.

# %%
plt.gca().fill_between(range(len(linear_data)),linear_data,quadratic_data,facecolor='brown',alpha=0.25)

# %%
plt.figure()
observation_data = np.arange('2017-01-01','2017-01-09', dtype='datetime64[D]')
plt.plot(observation_data,linear_data,'-o',observation_data,quadratic_data)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %% [markdown]
# USE toDate IN PANDAS LIBRRAY WHICH can dothe desired thing

# %%
import pandas as pd
plt.figure()
observation_data = np.arange('2017-01-01','2017-01-09', dtype='datetime64[D]')
observation_data = list(map(pd.to_datetime,observation_data))
plt.plot(observation_data,linear_data,'-o',observation_data,quadratic_data,'-o')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
x = plt.gca().xaxis
for item in x.get_ticklabels():
    item.set_rotation(45)

# %%
plt.subplots_adjust(bottom = .3)

# %% [markdown]
# # BAR CHARTS

# %%
plt.figure()
xvals = range(len(linear_data))
plt.bar(xvals, linear_data, width = 0.3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 8 artists>

# %%
new_xvals = []
for item in xvals:
    new_xvals.append(item+0.3)

plt.bar(new_xvals, quadratic_data, width=0.3, color='red')
# Out:
# <Container object of 8 artists>

# %%
from random import randint
linear_err = [randint(0,15) for x in range(len(linear_data))]
plt.bar(xvals, linear_data,width=0.3, yerr=linear_err)
# Out:
# <BarContainer object of 8 artists>

# %%
plt.figure()
xvals=range(len(linear_data))
plt.bar(xvals,linear_data,width=0.3,color='b')
plt.bar(xvals, quadratic_data, width=0.3,bottom=linear_data,color='r')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 8 artists>

# %%
plt.figure()
xvals=range(len(linear_data))
plt.bar(xvals,linear_data,width=0.3,color='b')
plt.bar(xvals, quadratic_data, width=0.3,bottom=linear_data,color='r')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Container object of 8 artists>

# %%
plt.figure()
xvals=range(len(linear_data))
plt.barh(xvals,linear_data,height=0.3,color='b')
plt.barh(xvals, quadratic_data, height=0.3,left=linear_data,color='r')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 8 artists>

# %%
import numpy as np

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

plt.bar(pos, popularity, align='center')
plt.xticks(pos, languages)
plt.ylabel('% Popularity')
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

#TODO: remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,    
    left='off',# ticks along the top edge are off
    labelbottom=False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
for spine in plt.gca().spines.values():
    spine.set_visible(False)
    
plt.show()#it remove the frame

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

# change the bar colors to be less bright blue
bars = plt.bar(pos, popularity, align='center', linewidth=0, color='lightslategrey')
# make one bar, the python bar, a contrasting color
bars[0].set_color('Blue')#1F77B4

# soften all labels by turning grey
plt.xticks(pos, languages, alpha=0.8)
plt.ylabel('% Popularity', alpha=0.8)
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

# remove the frame of the chart
for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\VIBIN\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

# change the bar color to be less bright blue
bars = plt.bar(pos, popularity, align='center', linewidth=0, color='lightslategrey')
# make one bar, the python bar, a contrasting color
bars[0].set_color('#1F77B4')

# soften all labels by turning grey
plt.xticks(pos, languages, alpha=0.8)
# remove the Y label since bars are directly labeled
#plt.ylabel('% Popularity', alpha=0.8)
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

# remove the frame of the chart
for spine in plt.gca().spines.values():
    spine.set_visible(False)
    
# direct label each bar with Y axis values
for bar in bars:
    plt.gca().text(bar.get_x() + bar.get_width()/2, bar.get_height() - 5, str(int(bar.get_height())) + '%', 
                 ha='center', color='w', fontsize=11)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# To select rows whose column value equals a scalar, some_value, use ==:
# df.loc[df['column_name'] == some_value]
#
# To select rows whose column value is in an iterable, some_values, use isin:
# df.loc[df['column_name'].isin(some_values)]
#
# Combine multiple conditions with &:
# df.loc[(df['column_name'] == some_value) & df['other_column'].isin(some_values)]
#
# To select rows whose column value does not equal some_value, use !=:
# df.loc[df['column_name'] != some_value]
#
# isin returns a boolean Series, so to select rows whose value is not in some_values, negate the boolean Series using ~:
# df.loc[~df['column_name'].isin(some_values)]

# %% [markdown]
# # SUBPLOTS

# %%
# %matplotlib notebook 
import matplotlib.pyplot as plt
import numpy as np
plt.subplot?

# %%
plt.figure()
plt.subplot(1,2,1)
linear_data = np.array([1,2,3,4,5,6])
plt.plot(linear_data,'-o')
exponential_data = linear_data**2
plt.subplot(1,2,2)
plt.plot(exponential_data,'-o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#the y axis is different . To avoid that 

plt.figure()
ax1 = plt.subplot(1, 2, 1)
plt.plot(linear_data, '-o')
ax2 = plt.subplot(1, 2, 2, sharey=ax1)
plt.plot(exponential_data, '-x')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ((ax1,ax2,ax3), (ax4,ax5,ax6), (ax7,ax8,ax9)) = plt.subplots(3,3,
                                                                 sharex=True,
                                                                 sharey=True)
ax5.plot(linear_data,'-')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
for ax in plt.gcf().get_axes():
    for label in ax.get_xticklabels() + ax.get_yticklabels():
        label.set_visible(True)

# %% [markdown]
# # histograms

# %%
fig, ((ax1,ax2), (ax3,ax4)) = plt.subplots(2,2,sharex = True)
axs = [ax1,ax2,ax3,ax4]

for n in range(0,len(axs)):
    sample_size = 10**(n+1)
    sample = np.random.normal(loc=0.0, scale=1.0, size = sample_size)
    axs[n].hist(sample)
    axs[n].set_title('n={}'.format(sample_size))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ((ax1,ax2), (ax3,ax4)) = plt.subplots(2,2,sharex = True)
axs = [ax1,ax2,ax3,ax4]

for n in range(0,len(axs)):
    sample_size = 10**(n+1)
    sample = np.random.normal(loc=0.0, scale=1.0, size = sample_size)
    axs[n].hist(sample, bins=100)
    axs[n].set_title('n={}'.format(sample_size))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
Y = np.random.normal(loc=0.0, scale =1.0, size=10000)
X = np.random.random(size=10000)
plt.scatter(X,Y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.gridspec as gridspec

plt.figure()
gspec = gridspec.GridSpec(3, 3)
top_histogram = plt.subplot(gspec[0,1:])
side_histogram = plt.subplot(gspec[1:,0])
lower_right=plt.subplot(gspec[1:,1:])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Y= np.random.normal(loc=0.0, scale=1.0,size=10000)
X= np.random.random(size=10000)

lower_right=plt.subplot(gspec[1:,1:])
lower_right.scatter(X,Y)
top_histogram.hist(X,bins=100)
s = side_histogram.hist(Y, bins=100, orientation = 'horizontal')
# Out:
# C:\Users\VIBIN\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
top_histogram.clear()
top_histogram.hist(X, bins=100, normed = True)
side_histogram.clear()
side_histogram.hist(Y, bins=100, orientation ='horizontal',normed=True)
side_histogram.invert_xaxis()
# Out:
# C:\Users\VIBIN\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# # Box And wWHISKER pLOTS

# %%
import pandas as pd
normal_sample = np.random.normal(loc=0.0,scale =1.0,size=10000)
random_sample = np.random.random(size=10000)
gamma_sample =np.random.gamma(2,size=10000)

df = pd.DataFrame({'normal':normal_sample,
      'random':random_sample,
      'gamma':gamma_sample})

# %%
df.describe()
# Out:
#               gamma        normal        random
# count  10000.000000  10000.000000  10000.000000
# mean       2.015442      0.011867      0.501207
# std        1.413127      1.000168      0.290378
# min        0.014602     -4.128708      0.000083
# 25%        0.990496     -0.671126      0.248979
# 50%        1.682141      0.015995      0.502960
# 75%        2.703097      0.692339      0.753286
# max       13.063330      3.580091      0.999974

# %%
plt.figure()
_ = plt.boxplot(df['normal'],whis='range')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.clf()
_ = plt.boxplot([df['normal'],df['random'],df['gamma']],whis='range')

# %%
plt.figure()
_= plt.hist(df['gamma'],bins=100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import mpl_toolkits.axes_gridl.inset_locator as mpl_il
plt.figure()
plt.boxplot([df['normal'], df['random'],df['gamma']],whis='range')
ax2 = mpl_il.inset_axes(plt.gca(), width='60%', height='40', loc =2)
ax2.hist(df['gamma'],bins=100)
ax2.margins(x=0.5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-78-99172d681f72> in <module>()
# ----> 1 import mpl_toolkits.axes_gridl.inset_locator as mpl_il
#       2 plt.figure()
#       3 plt.boxplot([df['normal'], df['random'],df['gamma']],whis='range')
#       4 ax2 = mpl_il.inset_axes(plt.gca(), width='60%', height='40', loc =2)
#       5 ax2.hist(df['gamma'],bins=100)
#
# ModuleNotFoundError: No module named 'mpl_toolkits.axes_gridl'

# %%
import importlib
importlib.import_module('mpl_toolkits').__path__
# Out:
# _NamespacePath(['C:\\Users\\VIBIN\\Anaconda3\\lib\\site-packages\\mpl_toolkits'])

# %% [markdown]
# # HEATMAPS

# %%
plt.figure()
Y =np.random.normal(loc = 0.0, scale=1.0, size = 10000)
X= np.random.random(size = 10000)
_ = plt.hist2d(X, Y, bins=25)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
_ = plt.hist2d(X, Y, bins=100)

# %%
plt.colorbar()

# %% [markdown]
# #  ANIMATION AND INTERACTIVITY

# %%
import matplotlib.animation as animation
n=100
x = np.random.randn(n)

# %%
#the function which will perform the animation . matplotlib will call this function every milliseconds 
# and pass in the fframe number starting from zero. first check the current index is n, if yes then stop animation

def update(curr):
    if curr ==n:
        a.event_source.stop()
    plt.cla()                                              #clear the current axis with cla
    bins = np.arange(-4, 4,0.5)                            #create a histogram using a set of value in the x
    plt.hist(x[:curr], bins = bins)                        #set axis othersisethe it will done automatically
    plt.hist([-4,4,0,30])
    plt.gca().set_title('Sampling the normal distributions')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    plt.annotate('n={}'.format(curr),[3,27])

# %%
fig=plt.figure()
a = animation.FuncAnimation(fig, update, interval=100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
data = np.random.rand(10)
plt.plot(data)

def onclick(event):
    plt.cla()
    plt.plot(data)
    plt.gca().set_title('Event at pixels {},{} and data {},{}'.format(event.x,event.y,'\n',event.xdata,event.ydata))
    
plt.gcf.canvas.mpl_connect('button press event at ',onclick)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-25039f7c2c19> in <module>()
#       8     plt.gca().set_title('Event at pixels {},{} and data {},{}'.format(event.x,event.y,'\n',event.xdata,event.ydata))
#       9
# ---> 10 plt.gcf.canvas.mpl_connect('button press event at ',onclick)
#
# AttributeError: 'function' object has no attribute 'canvas'
